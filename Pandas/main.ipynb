# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("pokemon_data.csv")

# %% [markdown]
# **Information Extraction**

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df["Name"][:5]
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
df[["Name" , "Type 1"]]
# Out:
#                       Name   Type 1
# 0                Bulbasaur    Grass
# 1                  Ivysaur    Grass
# 2                 Venusaur    Grass
# 3    VenusaurMega Venusaur    Grass
# 4               Charmander     Fire
# ..                     ...      ...
# 795                Diancie     Rock
# 796    DiancieMega Diancie     Rock
# 797    HoopaHoopa Confined  Psychic
# 798     HoopaHoopa Unbound  Psychic
# 799              Volcanion     Fire
#
# [800 rows x 2 columns]

# %%
df.iloc[0:4]
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
df.iloc[1 , 4]
# Out:
# 60

# %%
df.loc[df["Type 1"] == "Fire"][:4]
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
#
#    Sp. Def  Speed  Generation  Legendary
# 4       50     65           1      False
# 5       65     80           1      False
# 6       85    100           1      False
# 7       85    100           1      False

# %% [markdown]
# **Sorting/Describing data**

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.sort_values(["Name" , "HP"] , ascending = [False , True])
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# **Making Changes to Data**

# %%
#New Column
df["Total"] = df["HP"] + df["Attack"] + df["Defense"]
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    143
# ...

# %%
df = df.drop(columns = ["Total"])
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.iloc[: , 4:9].sum(axis = 1)
# Out:
# 0      273
# 1      345
# 2      445
# 3      545
# 4      244
#       ...
# 795    550
# 796    590
# 797    530
# 798    600
# 799    530
# Length: 800, dtype: int64

# %%
#Rearrange

cols = list(df.columns)
df = df[cols[:4] + [cols[-1]] + cols[4:12]]
df
# Out:
#        #                   Name   Type 1  Type 2  Legendary  HP  Attack  \
# 0      1              Bulbasaur    Grass  Poison      False  45      49
# 1      2                Ivysaur    Grass  Poison      False  60      62
# 2      3               Venusaur    Grass  Poison      False  80      82
# 3      3  VenusaurMega Venusaur    Grass  Poison      False  80     100
# 4      4             Charmander     Fire     NaN      False  39      52
# ..   ...                    ...      ...     ...        ...  ..     ...
# 795  719                Diancie     Rock   Fairy       True  50     100
# 796  719    DiancieMega Diancie     Rock   Fairy       True  50     160
# 797  720    HoopaHoopa Confined  Psychic   Ghost       True  80     110
# 798  720     HoopaHoopa Unbound  Psychic    Dark       True  80     160
# 799  721              Volcanion     Fire   Water       True  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# **Saving Data**

# %%
df.to_csv("modified.csv" , index = False ) #, sep='\t'

# %% [markdown]
# **Filtering Data**

# %%
# & or |
temp_df = df.loc[(df["Type 1"] == "Grass") & (df["Type 2"] == "Poison")]
temp_df
# Out:
#        #                   Name Type 1  Type 2  Legendary   HP  Attack  \
# 0      1              Bulbasaur  Grass  Poison      False   45      49
# 1      2                Ivysaur  Grass  Poison      False   60      62
# 2      3               Venusaur  Grass  Poison      False   80      82
# 3      3  VenusaurMega Venusaur  Grass  Poison      False   80     100
# 48    43                 Oddish  Grass  Poison      False   45      50
# 49    44                  Gloom  Grass  Poison      False   60      65
# 50    45              Vileplume  Grass  Poison      False   75      80
# 75    69             Bellsprout  Grass  Poison      False   50      75
# 76    70             Weepinbell  Grass  Poison      False   65      90
# 77    71             Victreebel  Grass  Poison      False   80     105
# 344  315                Roselia  Grass  Poison      False   50      60
# 451  406                  Budew  Grass  Poison      False   40      30
# ...

# %%
#Reset Index

temp_df = temp_df.reset_index(drop = False) #True to drop old index
df
# Out:
#        #                   Name   Type 1  Type 2  Legendary  HP  Attack  \
# 0      1              Bulbasaur    Grass  Poison      False  45      49
# 1      2                Ivysaur    Grass  Poison      False  60      62
# 2      3               Venusaur    Grass  Poison      False  80      82
# 3      3  VenusaurMega Venusaur    Grass  Poison      False  80     100
# 4      4             Charmander     Fire     NaN      False  39      52
# ..   ...                    ...      ...     ...        ...  ..     ...
# 795  719                Diancie     Rock   Fairy       True  50     100
# 796  719    DiancieMega Diancie     Rock   Fairy       True  50     160
# 797  720    HoopaHoopa Confined  Psychic   Ghost       True  80     110
# 798  720     HoopaHoopa Unbound  Psychic    Dark       True  80     160
# 799  721              Volcanion     Fire   Water       True  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
#Regex

df.loc[df["Name"].str.contains("Mega")][:4]
# Out:
#     #                       Name Type 1  Type 2  Legendary  HP  Attack  \
# 3   3      VenusaurMega Venusaur  Grass  Poison      False  80     100
# 7   6  CharizardMega Charizard X   Fire  Dragon      False  78     130
# 8   6  CharizardMega Charizard Y   Fire  Flying      False  78     104
# 12  9    BlastoiseMega Blastoise  Water     NaN      False  79     103
#
#     Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 3       123      122      120     80           1      False
# 7       111      130       85    100           1      False
# 8        78      159      115    100           1      False
# 12      120      135      115     78           1      False

# %%
df.loc[~df["Name"].str.contains("Mega")]
# Out:
#        #                 Name   Type 1  Type 2  Legendary   HP  Attack  \
# 0      1            Bulbasaur    Grass  Poison      False   45      49
# 1      2              Ivysaur    Grass  Poison      False   60      62
# 2      3             Venusaur    Grass  Poison      False   80      82
# 4      4           Charmander     Fire     NaN      False   39      52
# 5      5           Charmeleon     Fire     NaN      False   58      64
# ..   ...                  ...      ...     ...        ...  ...     ...
# 794  718     Zygarde50% Forme   Dragon  Ground       True  108     100
# 795  719              Diancie     Rock   Fairy       True   50     100
# 797  720  HoopaHoopa Confined  Psychic   Ghost       True   80     110
# 798  720   HoopaHoopa Unbound  Psychic    Dark       True   80     160
# 799  721            Volcanion     Fire   Water       True   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
import re

df.loc[df["Type 1"].str.contains("Fire|Grass" , flags = re.I , regex = True)]
# Out:
#        #                   Name Type 1  Type 2  Legendary   HP  Attack  \
# 0      1              Bulbasaur  Grass  Poison      False   45      49
# 1      2                Ivysaur  Grass  Poison      False   60      62
# 2      3               Venusaur  Grass  Poison      False   80      82
# 3      3  VenusaurMega Venusaur  Grass  Poison      False   80     100
# 4      4             Charmander   Fire     NaN      False   39      52
# ..   ...                    ...    ...     ...        ...  ...     ...
# 735  667                 Litleo   Fire  Normal      False   62      50
# 736  668                 Pyroar   Fire  Normal      False   86      68
# 740  672                 Skiddo  Grass     NaN      False   66      65
# 741  673                 Gogoat  Grass     NaN      False  123     100
# 799  721              Volcanion   Fire   Water       True   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# **Conditional Changes**

# %%
df.loc[df["Type 1"] == "Fire" , "Type 1"] = "Flamer"
df
# Out:
#        #                   Name   Type 1  Type 2  Legendary  HP  Attack  \
# 0      1              Bulbasaur    Grass  Poison      False  45      49
# 1      2                Ivysaur    Grass  Poison      False  60      62
# 2      3               Venusaur    Grass  Poison      False  80      82
# 3      3  VenusaurMega Venusaur    Grass  Poison      False  80     100
# 4      4             Charmander   Flamer     NaN      False  39      52
# ..   ...                    ...      ...     ...        ...  ..     ...
# 795  719                Diancie     Rock   Fairy       True  50     100
# 796  719    DiancieMega Diancie     Rock   Fairy       True  50     160
# 797  720    HoopaHoopa Confined  Psychic   Ghost       True  80     110
# 798  720     HoopaHoopa Unbound  Psychic    Dark       True  80     160
# 799  721              Volcanion   Flamer   Water       True  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.loc[df["Attack"] > 50 , ["Generation" , "Legendary"]] = "TEST VALUE"
df
# Out:
# C:\Users\thunk\AppData\Local\Temp\ipykernel_14668\3705917037.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'TEST VALUE' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df["Attack"] > 50 , ["Generation" , "Legendary"]] = "TEST VALUE"
# C:\Users\thunk\AppData\Local\Temp\ipykernel_14668\3705917037.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'TEST VALUE' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   df.loc[df["Attack"] > 50 , ["Generation" , "Legendary"]] = "TEST VALUE"
#        #                   Name   Type 1  Type 2   Legendary  HP  Attack  \
# 0      1              Bulbasaur    Grass  Poison       False  45      49
# 1      2                Ivysaur    Grass  Poison  TEST VALUE  60      62
# ...

# %% [markdown]
# **Aggregate Statistic**

# %%
df = df.drop(columns= ["Legendary"])
df.groupby(["Type 1"]).count()
# Out:
#             #  Name  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Bug        69    69      52   69      69       69       69       69     69
# Dark       31    31      21   31      31       31       31       31     31
# Dragon     32    32      21   32      32       32       32       32     32
# Electric   44    44      17   44      44       44       44       44     44
# Fairy      17    17       2   17      17       17       17       17     17
# Fighting   27    27       7   27      27       27       27       27     27
# Flamer     52    52      24   52      52       52       52       52     52
# Flying      4     4       2    4       4        4        4        4      4
# Ghost      32    32      22   32      32       32       32       32     32
# Grass      70    70      37   70      70       70       70       70     70
# Ground     32    32      19   32      32       32       32       32     32
# ...

# %% [markdown]
# **Large Data**

# %%
df = pd.DataFrame(columns = df.columns)

for df in pd.read_csv("modified.csv" , chunksize = 5):
    results = df.groupby(["Type 1"]).count()
